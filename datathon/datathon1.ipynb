# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("train.csv", index_col="index")
df.head(50;)
# Out:
#   Cell In[20], line 2
#     df.head(50;)
#               ^
# SyntaxError: invalid syntax

# %%
filtrelidata=  df[df["İstihdam Durumu"] == "Kendi İşinin Sahibi"]
filtrelidata.head(100)
# Out:
#       Cinsiyet Yaş Grubu Medeni Durum      Eğitim Düzeyi      İstihdam Durumu  \
# index
# 1        Erkek       >60         Evli        Lise Mezunu  Kendi İşinin Sahibi
# 3        Erkek     51-60         Evli        Lise Mezunu  Kendi İşinin Sahibi
# 7        Kadın     31-40        Bekar        Lise Mezunu  Kendi İşinin Sahibi
# 13       Erkek     51-60         Evli  Üniversite Mezunu  Kendi İşinin Sahibi
# 24       Erkek     31-40        Bekar  Üniversite Mezunu  Kendi İşinin Sahibi
# ...        ...       ...          ...                ...                  ...
# 693      Erkek     18-30        Bekar        Lise Mezunu  Kendi İşinin Sahibi
# 699      Erkek       >60         Evli        Lise Mezunu  Kendi İşinin Sahibi
# 704      Kadın     18-30         Evli        Lise Mezunu  Kendi İşinin Sahibi
# 707      Erkek     31-40         Evli     İlkokul Mezunu  Kendi İşinin Sahibi
# 712      Erkek     51-60        Bekar  Üniversite Mezunu  Kendi İşinin Sahibi
#
# ...

# %%
filtrelidata.query("`Yaş Grubu` == '31-40'").head(10)
# Out:
#       Cinsiyet Yaş Grubu Medeni Durum         Eğitim Düzeyi  \
# index
# 7        Kadın     31-40        Bekar           Lise Mezunu
# 24       Erkek     31-40        Bekar     Üniversite Mezunu
# 47       Erkek     31-40         Evli           Lise Mezunu
# 61       Erkek     31-40         Evli           Lise Mezunu
# 126      Erkek     31-40        Bekar           Lise Mezunu
# 135      Erkek     31-40         Evli           Lise Mezunu
# 150      Erkek     31-40         Evli       Ortaokul Mezunu
# 160      Erkek     31-40        Bekar        Doktora Mezunu
# 168      Kadın     31-40        Bekar       Ortaokul Mezunu
# 179      Kadın     31-40         Evli  Yüksek Lisans Mezunu
#
#            İstihdam Durumu  Yıllık Ortalama Gelir   Yaşadığı Şehir  \
# index
# 7      Kendi İşinin Sahibi          213630.355636      Küçük Şehir
# 24     Kendi İşinin Sahibi          141995.912615  Köy veya Kasaba
# 47     Kendi İşinin Sahibi          161332.822602      Küçük Şehir
# ...

# %%
df.isna().sum()
# Out:
# Cinsiyet                                      0
# Yaş Grubu                                     0
# Medeni Durum                                  0
# Eğitim Düzeyi                                 0
# İstihdam Durumu                               0
# Yıllık Ortalama Gelir                         0
# Yaşadığı Şehir                                0
# En Çok İlgilendiği Ürün Grubu                 0
# Yıllık Ortalama Satın Alım Miktarı            0
# Yıllık Ortalama Sipariş Verilen Ürün Adedi    0
# Eğitime Devam Etme Durumu                     0
# Öbek İsmi                                     0
# Yıllık Ortalama Sepete Atılan Ürün Adedi      0
# dtype: int64

# %%
df["Eğitim Düz
   eyi"].value_counts()
# Out:
# Lise Mezunu             1388
# Üniversite Mezunu       1257
# Yüksekokul Mezunu        588
# Yüksek Lisans Mezunu     545
# İlkokul Mezunu           417
# Ortaokul Mezunu          412
# Eğitimsiz                381
# Doktora Mezunu           263
# Doktora Ötesi            209
# Name: Eğitim Düzeyi, dtype: int64

# %%
df.describe().T
# Out:
#                                              count           mean  \
# Yıllık Ortalama Gelir                       5460.0  363571.133428
# Yıllık Ortalama Satın Alım Miktarı          5460.0   16616.612217
# Yıllık Ortalama Sipariş Verilen Ürün Adedi  5460.0      24.040884
# Yıllık Ortalama Sepete Atılan Ürün Adedi    5460.0      73.445693
#
#                                                       std           min  \
# Yıllık Ortalama Gelir                       219714.442407  43922.988693
# Yıllık Ortalama Satın Alım Miktarı           14099.171704   2859.254000
# Yıllık Ortalama Sipariş Verilen Ürün Adedi      14.945655      0.000000
# Yıllık Ortalama Sepete Atılan Ürün Adedi        47.214184      3.977559
#
#                                                       25%            50%  \
# Yıllık Ortalama Gelir                       215693.439307  286925.436073
# Yıllık Ortalama Satın Alım Miktarı            4931.859057    8426.818967
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5460 entries, 0 to 5459
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Cinsiyet                                    5460 non-null   object
#  1   Yaş Grubu                                   5460 non-null   object
#  2   Medeni Durum                                5460 non-null   object
#  3   Eğitim Düzeyi                               5460 non-null   object
#  4   İstihdam Durumu                             5460 non-null   object
#  5   Yıllık Ortalama Gelir                       5460 non-null   float64
#  6   Yaşadığı Şehir                              5460 non-null   object
#  7   En Çok İlgilendiği Ürün Grubu               5460 non-null   object
#  8   Yıllık Ortalama Satın Alım Miktarı          5460 non-null   float64
# ...

# %%
df.corr()
# Out:
# /var/folders/39/15zp5wjs7wq3fwkgthfgz4bc0000gn/T/ipykernel_26296/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                             Yıllık Ortalama Gelir  \
# Yıllık Ortalama Gelir                                    1.000000
# Yıllık Ortalama Satın Alım Miktarı                       0.740238
# Yıllık Ortalama Sipariş Verilen Ürün Adedi               0.444398
# Yıllık Ortalama Sepete Atılan Ürün Adedi                 0.145425
#
#                                             Yıllık Ortalama Satın Alım Miktarı  \
# Yıllık Ortalama Gelir                                                 0.740238
# Yıllık Ortalama Satın Alım Miktarı                                    1.000000
# Yıllık Ortalama Sipariş Verilen Ürün Adedi                            0.418499
# ...

# %%
encoded_df = pd.get_dummies(df, columns=['Cinsiyet', 'Yaş Grubu',"İstihdam Durumu","En Çok İlgilendiği Ürün Grubu","Eğitim Düzeyi"])

# %%
encoded_df.head()
# Out:
#        Yıllık Ortalama Gelir Yaşadığı Şehir  \
# index
# 0              748266.440879    Büyük Şehir
# 1              246298.609605    Küçük Şehir
# 2              268582.732360    Küçük Şehir
# 3              327721.837865         Kırsal
# 4              397431.626948    Büyük Şehir
#
#        Yıllık Ortalama Satın Alım Miktarı  \
# index
# 0                            32010.900881
# 1                             4145.729891
# 2                             9924.379414
# 3                             6417.780714
# 4                             7886.663061
#
#        Yıllık Ortalama Sipariş Verilen Ürün Adedi Eğitime Devam Etme Durumu  \
# index
# 0                                       37.310644                   Etmiyor
# 1                                       11.554851                   Etmiyor
# 2                                       55.353236                    Ediyor
# 3                                       15.417239                   Etmiyor
# ...

# %%
encoded_df.corr()
# Out:
# /var/folders/39/15zp5wjs7wq3fwkgthfgz4bc0000gn/T/ipykernel_26296/1102433409.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   encoded_df.corr()
#                                                     Yıllık Ortalama Gelir  \
# Yıllık Ortalama Gelir                                            1.000000
# Yıllık Ortalama Satın Alım Miktarı                               0.740238
# Yıllık Ortalama Sipariş Verilen Ürün Adedi                       0.444398
# Yıllık Ortalama Sepete Atılan Ürün Adedi                         0.145425
# Cinsiyet_Erkek                                                   0.019209
# Cinsiyet_Kadın                                                  -0.019209
# Yaş Grubu_18-30                                                 -0.060893
# ...
